# %% [markdown]
# ## Inferencing in CPU

# %%
# %cd yolov9
# !pwd
# Out:
# /home/shiv-nlp-mldl-cv/anaconda3/envs/S15-Yolo1/lib/python3.10/site-packages/IPython/core/magics/osm.py:393: UserWarning: using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# [Errno 2] No such file or directory: 'yolov9'
# /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9
# /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9

# %%
# !pwd
# Out:
# /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9

# %% [markdown]
# #### Image 1  -- Car

# %%
# !python detect_dual.py --source data/images/lamborghini-aventador-2932196_1280.jpg --img 640 --device cpu --weights runs/train/exp/weights/best.pt --name yolov9_c_640_detect16
# Out:
# detect_dual: weights=['runs/train/exp/weights/best.pt'], source=data/images/lamborghini-aventador-2932196_1280.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolov9_c_640_detect16, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.14 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68555524 parameters, 0 gradients, 240.7 GFLOPs
# image 1/1 /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/data/images/lamborghini-aventador-2932196_1280.jpg: 448x640 2 cars, 1955.7ms
# Speed: 0.8ms pre-process, 1955.7ms inference, 1.1ms NMS per image at shape (1, 3, 640, 640)
# ...

# %%
from IPython.display import Image

Image(filename=f"/home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/runs/detect/yolov9_c_640_detect162/lamborghini-aventador-2932196_1280.jpg", width=1000)

# %% [markdown]
# #### Image 2  -- Truck

# %%
# !python detect_dual.py --source /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/data/images/rohan.jpg --img 640 --device cpu --weights /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/runs/train/exp/weights/last.pt --name yolov9_c_640_detect18
# Out:
# detect_dual: weights=['/home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/runs/train/exp/weights/last.pt'], source=/home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/data/images/rohan.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolov9_c_640_detect18, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.14 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68555524 parameters, 0 gradients, 240.7 GFLOPs
# image 1/1 /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/data/images/rohan.jpg: 352x640 1 truck, 1613.9ms
# ...

# %%
from IPython.display import Image

Image(filename=f"/home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/runs/detect/yolov9_c_640_detect183/rohan.jpg", width=1000)

# %%
# !python detect_dual.py --source /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/data/images/bike.png --img 640 --device cpu --weights /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/runs/train/exp/weights/best.pt --name yolov9_c_640_detect20
# Out:
# detect_dual: weights=['/home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/runs/train/exp/weights/best.pt'], source=/home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/data/images/bike.png, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=cpu, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=yolov9_c_640_detect20, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLO 🚀 v0.1-89-g93f1a28 Python-3.10.14 torch-2.3.0+cu121 CPU
#
# Fusing layers...
# yolov9-e summary: 839 layers, 68555524 parameters, 0 gradients, 240.7 GFLOPs
# image 1/1 /home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/data/images/bike.png: 512x640 1 motorbike, 2077.8ms
# ...

# %% [markdown]
# #### Image 3  -- Bike

# %%
from IPython.display import Image

Image(filename=f"/home/shiv-nlp-mldl-cv/Documents/ERA2Code/ERA2-Session-15_Inference_Code/yolov9/runs/detect/yolov9_c_640_detect20/bike.png", width=1000)
